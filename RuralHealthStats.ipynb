# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##2005 data##

# %%
d1=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_2005.csv')
d1.drop([23,34,37,29],inplace=True)##Removing Ladakh,Telangana,Chandigarh with total population
d1.fillna(value=0,inplace=True)##Filling Empty Values
d1
# Out:
#                 State/UT SubCenters  PHCs CHCs ANM/Health_Worker_Female  \
# 0         Andhra Pradesh      12522  1570  164                    13740
# 1      Arunachal Pradesh        379    85   31                      454
# 2                  Assam       5109   610  100                     5719
# 3                  Bihar      10337  1648  101                        0
# 4           Chhattisgarh       3818   517  116                     3667
# 5                    Goa        172    19    5                      179
# 6                Gujarat       7274  1070  272                     6508
# 7                Haryana       2433   408   72                     2818
# 8       Himachal Pradesh       2068   439   66                     1790
# 9              Jharkhand       4462   561   47                        0
# 10             Karnataka       8143  1681  254                     8544
# 11                Kerala       5094   911  106                     5565
# ...

# %%
d1['HealthCare Centers'] = d1["SubCenters"].astype(str).astype(int) +d1["PHCs"].astype(str).astype(int)+d1["CHCs"].astype(str).astype(int)
d1['Doctor'] = d1["Doctors"].astype(str).astype(int) +d1["Specialists"].astype(str).astype(int)
d1['HealthCare&Nursing Staff'] = d1["ANM/Health_Worker_Female"].astype(str).astype(int) +d1["NursingStaff"].astype(str).astype(int)
d1['Secondline HealthCare Centers'] = d1["Radiographers"].astype(str).astype(int) +d1["Pharmacists"].astype(str).astype(int)+d1["LabTechinicians"].astype(str).astype(int)
d1
# Out:
#                 State/UT SubCenters  PHCs CHCs ANM/Health_Worker_Female  \
# 0         Andhra Pradesh      12522  1570  164                    13740
# 1      Arunachal Pradesh        379    85   31                      454
# 2                  Assam       5109   610  100                     5719
# 3                  Bihar      10337  1648  101                        0
# 4           Chhattisgarh       3818   517  116                     3667
# 5                    Goa        172    19    5                      179
# 6                Gujarat       7274  1070  272                     6508
# 7                Haryana       2433   408   72                     2818
# 8       Himachal Pradesh       2068   439   66                     1790
# 9              Jharkhand       4462   561   47                        0
# 10             Karnataka       8143  1681  254                     8544
# 11                Kerala       5094   911  106                     5565
# ...

# %%
d1.drop(['SubCenters','PHCs','CHCs','ANM/Health_Worker_Female','Doctors','Specialists','Radiographers','Pharmacists','LabTechinicians','NursingStaff'],axis=1,inplace=True)
d1.reset_index(drop=True, inplace=True)
d1
# Out:
#                 State/UT  HealthCare Centers  Doctor  \
# 0         Andhra Pradesh               14256    2361
# 1      Arunachal Pradesh                 495      78
# 2                  Assam                5819       0
# 3                  Bihar               12086       0
# 4           Chhattisgarh                4451     646
# 5                    Goa                 196      60
# 6                Gujarat                8616     940
# 7                Haryana                2913     911
# 8       Himachal Pradesh                2573     467
# 9              Jharkhand                5070       0
# 10             Karnataka               10078    2732
# 11                Kerala                6111    1031
# 12        Madhya Pradesh               10295     888
# 13           Maharashtra               12615    4257
# 14               Manipur                 508      86
# 15             Meghalaya                 526     124
# 16               Mizoram                 432      35
# ...

# %%
d1['Doctor']=d1['Doctor'].replace(0,d1['Doctor'].mean())
d1['HealthCare&Nursing Staff']=d1['HealthCare&Nursing Staff'].replace(0,d1['HealthCare&Nursing Staff'].mean())
d1['Secondline HealthCare Centers']=d1['Secondline HealthCare Centers'].replace(0,d1['Secondline HealthCare Centers'].mean())
d1
# Out:
#                 State/UT  HealthCare Centers       Doctor  \
# 0         Andhra Pradesh               14256  2361.000000
# 1      Arunachal Pradesh                 495    78.000000
# 2                  Assam                5819   701.588235
# 3                  Bihar               12086   701.588235
# 4           Chhattisgarh                4451   646.000000
# 5                    Goa                 196    60.000000
# 6                Gujarat                8616   940.000000
# 7                Haryana                2913   911.000000
# 8       Himachal Pradesh                2573   467.000000
# 9              Jharkhand                5070   701.588235
# 10             Karnataka               10078  2732.000000
# 11                Kerala                6111  1031.000000
# 12        Madhya Pradesh               10295   888.000000
# 13           Maharashtra               12615  4257.000000
# 14               Manipur                 508    86.000000
# ...

# %%
Rural_Pop_2005=[55401000,870000,23216000,74314000,16648000,677000,31741000,15029000,5482000,20952000,34889000,23574000,44381000,55778000,1718000,1865000,448000,1647000,31287000,16096000,43293000,481000,34922000,2653000,6310000,131658000,57749000,240000,170000,101000,945000,7627000,34000,326000]
d1['Rural_Pop']=Rural_Pop_2005
d1
# Out:
#                 State/UT  HealthCare Centers       Doctor  \
# 0         Andhra Pradesh               14256  2361.000000
# 1      Arunachal Pradesh                 495    78.000000
# 2                  Assam                5819   701.588235
# 3                  Bihar               12086   701.588235
# 4           Chhattisgarh                4451   646.000000
# 5                    Goa                 196    60.000000
# 6                Gujarat                8616   940.000000
# 7                Haryana                2913   911.000000
# 8       Himachal Pradesh                2573   467.000000
# 9              Jharkhand                5070   701.588235
# 10             Karnataka               10078  2732.000000
# 11                Kerala                6111  1031.000000
# 12        Madhya Pradesh               10295   888.000000
# 13           Maharashtra               12615  4257.000000
# 14               Manipur                 508    86.000000
# ...

# %%
d1['Rural Pop to Doc Ratio']=d1['Rural_Pop']/d1['Doctor']
d1['Rural Pop to HealthCare Staff Ratio']=d1['Rural_Pop']/d1['HealthCare&Nursing Staff']
d1
# Out:
#                 State/UT  HealthCare Centers       Doctor  \
# 0         Andhra Pradesh               14256  2361.000000
# 1      Arunachal Pradesh                 495    78.000000
# 2                  Assam                5819   701.588235
# 3                  Bihar               12086   701.588235
# 4           Chhattisgarh                4451   646.000000
# 5                    Goa                 196    60.000000
# 6                Gujarat                8616   940.000000
# 7                Haryana                2913   911.000000
# 8       Himachal Pradesh                2573   467.000000
# 9              Jharkhand                5070   701.588235
# 10             Karnataka               10078  2732.000000
# 11                Kerala                6111  1031.000000
# 12        Madhya Pradesh               10295   888.000000
# 13           Maharashtra               12615  4257.000000
# 14               Manipur                 508    86.000000
# ...

# %%
## 2019 Data ##

# %%
d2=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_2019.csv')
d2.drop([34,37],inplace=True)
d2
# Out:
#                 State/UT SubCenters  PHCs CHCs ANM/Health_Worker_Female  \
# 0         Andhra Pradesh       7437  1145  140                    11815
# 1      Arunachal Pradesh        385   143   63                      689
# 2                  Assam       4643   946  177                    11502
# 3                  Bihar       9949  1899  150                    24228
# 4           Chhattisgarh       5205   792  170                     6808
# 5                    Goa        219    24    5                      250
# 6                Gujarat       9166  1476  362                     9168
# 7                Haryana       2604   379  115                     4606
# 8       Himachal Pradesh       2089   586   87                     1845
# 9              Jharkhand       3848   298  171                     6325
# 10             Karnataka       9758  2127  198                     8462
# 11                Kerala       5380   848  227                     7504
# ...

# %%
d2['HealthCare Centers'] = d2["SubCenters"].astype(str).astype(int) +d2["PHCs"].astype(str).astype(int)+d2["CHCs"].astype(str).astype(int)
d2['Doctor'] = d2["Doctors"].astype(str).astype(int) +d2["Specialists"].astype(str).astype(int)
d2['HealthCare&Nursing Staff'] = d2["ANM/Health_Worker_Female"].astype(str).astype(int) +d2["NursingStaff"].astype(str).astype(int)
d2['Secondline HealthCare Centers'] = d2["Radiographers"].astype(str).astype(int) +d2["Pharmacists"].astype(str).astype(int)+d2["LabTechnicians"].astype(str).astype(int)
d2
# Out:
#                 State/UT SubCenters  PHCs CHCs ANM/Health_Worker_Female  \
# 0         Andhra Pradesh       7437  1145  140                    11815
# 1      Arunachal Pradesh        385   143   63                      689
# 2                  Assam       4643   946  177                    11502
# 3                  Bihar       9949  1899  150                    24228
# 4           Chhattisgarh       5205   792  170                     6808
# 5                    Goa        219    24    5                      250
# 6                Gujarat       9166  1476  362                     9168
# 7                Haryana       2604   379  115                     4606
# 8       Himachal Pradesh       2089   586   87                     1845
# 9              Jharkhand       3848   298  171                     6325
# 10             Karnataka       9758  2127  198                     8462
# 11                Kerala       5380   848  227                     7504
# ...

# %%
d2.drop(['SubCenters','PHCs','CHCs','ANM/Health_Worker_Female','Doctors','Specialists','Radiographers','Pharmacists','LabTechnicians','NursingStaff'],axis=1,inplace=True)
d2
# Out:
#                 State/UT  HealthCare Centers  Doctor  \
# 0         Andhra Pradesh                8722    1952
# 1      Arunachal Pradesh                 591     120
# 2                  Assam                5766    2061
# 3                  Bihar               11998    2167
# 4           Chhattisgarh                6167     382
# 5                    Goa                 248      61
# 6                Gujarat               11004    2304
# 7                Haryana                3098     557
# 8       Himachal Pradesh                2762     491
# 9              Jharkhand                4317     402
# 10             Karnataka               12083    2576
# 11                Kerala                6455    1566
# 12        Madhya Pradesh               11734    1157
# 13           Maharashtra               12860    3436
# 14               Manipur                 603     211
# 15             Meghalaya                 623     153
# 16               Mizoram                 438      60
# ...

# %%
d2
# Out:
#                 State/UT  HealthCare Centers  Doctor  \
# 0         Andhra Pradesh                8722    1952
# 1      Arunachal Pradesh                 591     120
# 2                  Assam                5766    2061
# 3                  Bihar               11998    2167
# 4           Chhattisgarh                6167     382
# 5                    Goa                 248      61
# 6                Gujarat               11004    2304
# 7                Haryana                3098     557
# 8       Himachal Pradesh                2762     491
# 9              Jharkhand                4317     402
# 10             Karnataka               12083    2576
# 11                Kerala                6455    1566
# 12        Madhya Pradesh               11734    1157
# 13           Maharashtra               12860    3436
# 14               Manipur                 603     211
# 15             Meghalaya                 623     153
# 16               Mizoram                 438      60
# ...

# %%
d2['State/UT'][30]='D&D and D&DNH'
d2['HealthCare Centers'][30]=82+27
d2['Doctor'][30]=15
d2['HealthCare&Nursing Staff'][30]=188+63
d2['Secondline HealthCare Centers'][30]=33+8
d2.drop([29],inplace=True)
d2.reset_index(drop=True, inplace=True)
d2
# Out:
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
d2.drop([30],inplace=True)
d2.reset_index(drop=True, inplace=True)
d2
# Out:
#              State/UT  HealthCare Centers  Doctor  HealthCare&Nursing Staff  \
# 0      Andhra Pradesh                8722    1952                     14676
# 1   Arunachal Pradesh                 591     120                      1306
# 2               Assam                5766    2061                     14871
# 3               Bihar               11998    2167                     25858
# 4        Chhattisgarh                6167     382                      9426
# 5                 Goa                 248      61                       385
# 6             Gujarat               11004    2304                     13386
# 7             Haryana                3098     557                      6716
# 8    Himachal Pradesh                2762     491                      2249
# 9           Jharkhand                4317     402                      7515
# 10          Karnataka               12083    2576                     11973
# ...

# %%
ar=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_villages_districs_area.csv')
ar.drop(['Urban_Area','Number_of_Districts','Number_of_Villages','Tribal_Area'],axis=1,inplace=True)
ar.fillna(value=0,inplace=True)
ar.drop([36,33,29],inplace=True)
ar.reset_index(drop=True, inplace=True)
ar['Rural_Area'][1]=83743.0
ar['Rural_%'][1]=100.0
ar
# Out:
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                           State/UT  Rural_Area  Total_Area  Rural_%
# 0                  Andhra Pradesh*   158856.00    162975.0    97.47
# 1                Arunachal Pradesh    83743.00     83743.0   100.00
# 2                            Assam    77178.12     78438.0    98.39
# 3                            Bihar    91838.28     94163.0    97.53
# ...

# %%
##concat 2019 data with area data##

# %%
d2['Rural_Area']=ar['Rural_Area']
d2['Total_Area']=ar['Total_Area']
d2['Rural_%']=ar['Rural_%']
d2
# Out:
#              State/UT  HealthCare Centers  Doctor  HealthCare&Nursing Staff  \
# 0      Andhra Pradesh                8722    1952                     14676
# 1   Arunachal Pradesh                 591     120                      1306
# 2               Assam                5766    2061                     14871
# 3               Bihar               11998    2167                     25858
# 4        Chhattisgarh                6167     382                      9426
# 5                 Goa                 248      61                       385
# 6             Gujarat               11004    2304                     13386
# 7             Haryana                3098     557                      6716
# 8    Himachal Pradesh                2762     491                      2249
# 9           Jharkhand                4317     402                      7515
# 10          Karnataka               12083    2576                     11973
# ...

# %%
d2['HealthCare Density']=d2['HealthCare Centers']/d2['Rural_Area']
d2['Doctor Density']=d2['Doctor']/d2['Rural_Area']
d2['HealthCare&Nursing Staff Density']=d2['HealthCare&Nursing Staff']/d2['Rural_Area']
d2['Secondline HealthCare Centers Density']=d2['Secondline HealthCare Centers']/d2['Rural_Area']
d2
# Out:
#              State/UT  HealthCare Centers  Doctor  HealthCare&Nursing Staff  \
# 0      Andhra Pradesh                8722    1952                     14676
# 1   Arunachal Pradesh                 591     120                      1306
# 2               Assam                5766    2061                     14871
# 3               Bihar               11998    2167                     25858
# 4        Chhattisgarh                6167     382                      9426
# 5                 Goa                 248      61                       385
# 6             Gujarat               11004    2304                     13386
# 7             Haryana                3098     557                      6716
# 8    Himachal Pradesh                2762     491                      2249
# 9           Jharkhand                4317     402                      7515
# 10          Karnataka               12083    2576                     11973
# ...

# %%
pop=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_population_density.csv')
pop.drop(['Urban_Population','Urban_Population_Density','Total_Population_Density'],axis=1,inplace=True)
pop.drop([29,33,36],inplace=True)
pop.reset_index(drop=True,inplace=True)
pop
# Out:
#                           State/UT  Rural_Population Rural_Population_Density  \
# 0                 Andhra Pradesh**          34256000                      216
# 1                Arunachal Pradesh           1141000                      NaN
# 2                            Assam          29492000                      382
# 3                            Bihar         107187000                     1167
# 4                     Chhattisgarh          21557000                      164
# 5                              Goa            421000                      145
# 6                          Gujarat          36380000                      193
# 7                          Haryana          17374000                      411
# 8                 Himachal Pradesh           6608000                      119
# 9                        Jharkhand          28313000                      365
# 10                       Karnataka          37815000                      204
# ...

# %%
d2['Rural_Population']=pop['Rural_Population']
d2['Rural_Population_Density']=pop['Rural_Population_Density']
d2['Rural_Population_%']=pop['Rural_Population_%']
d2
# Out:
#              State/UT  HealthCare Centers  Doctor  HealthCare&Nursing Staff  \
# 0      Andhra Pradesh                8722    1952                     14676
# 1   Arunachal Pradesh                 591     120                      1306
# 2               Assam                5766    2061                     14871
# 3               Bihar               11998    2167                     25858
# 4        Chhattisgarh                6167     382                      9426
# 5                 Goa                 248      61                       385
# 6             Gujarat               11004    2304                     13386
# 7             Haryana                3098     557                      6716
# 8    Himachal Pradesh                2762     491                      2249
# 9           Jharkhand                4317     402                      7515
# 10          Karnataka               12083    2576                     11973
# ...

# %%
d2['Rural Pop to Doc Ratio']=d2['Rural_Population']/d2['Doctor']
d2['Rural Pop to HealthCare Staff Ratio']=d2['Rural_Population']/d2['HealthCare&Nursing Staff']
d2
# Out:
#              State/UT  HealthCare Centers  Doctor  HealthCare&Nursing Staff  \
# 0      Andhra Pradesh                8722    1952                     14676
# 1   Arunachal Pradesh                 591     120                      1306
# 2               Assam                5766    2061                     14871
# 3               Bihar               11998    2167                     25858
# 4        Chhattisgarh                6167     382                      9426
# 5                 Goa                 248      61                       385
# 6             Gujarat               11004    2304                     13386
# 7             Haryana                3098     557                      6716
# 8    Himachal Pradesh                2762     491                      2249
# 9           Jharkhand                4317     402                      7515
# 10          Karnataka               12083    2576                     11973
# ...

# %%
d2.sort_values(by=['Rural Pop to Doc Ratio'], inplace=False, ascending=False)
# Out:
#              State/UT  HealthCare Centers  Doctor  HealthCare&Nursing Staff  \
# 27        West Bengal               11613     881                     24808
# 9           Jharkhand                4317     402                      7515
# 4        Chhattisgarh                6167     382                      9426
# 12     Madhya Pradesh               11734    1157                     14640
# 3               Bihar               11998    2167                     25858
# 26      Uttar Pradesh               24397    3664                     47586
# 18             Odisha                8353    1049                     11755
# 7             Haryana                3098     557                      6716
# 30              Delhi                  17       5                        24
# 19             Punjab                3455     655                      6336
# 25        Uttarakhand                2171     296                      2154
# ...

# %%
##2020 Data##

# %%
d3=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_2020.csv')
d3.drop([29,31,37],inplace=True)
d3['Specialists'][32]=0
d3['Radiographers'][32]=0
d3['HealthCare Centers'] = d3["SubCenters"].astype(str).astype(float) +d3["PHCs"].astype(str).astype(float)+d3["CHCs"].astype(str).astype(float)
d3['Doctor'] = d3["Doctors"].astype(str).astype(int) +d3["Specialists"].astype(str).astype(int)
d3['HealthCare&Nursing Staff'] = d3["ANM/Health_Worker_Female"].astype(str).astype(int) +d3["NursingStaff"].astype(str).astype(int)
d3['Secondline HealthCare Centers'] = d3["Radiographers"].astype(str).astype(int) +d3["Pharmacists"].astype(str).astype(int)+d3["LabTechnicians"].astype(str).astype(int)
d3.drop(['SubCenters','PHCs','CHCs','ANM/Health_Worker_Female','Doctors','Specialists','Radiographers','Pharmacists','LabTechnicians','NursingStaff'],axis=1,inplace=True)
d3.reset_index(drop=True,inplace=True)
d3
# Out:
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                 State/UT  HealthCare Centers  Doctor  \
# 0         Andhra Pradesh              8720.0    2113
# 1      Arunachal Pradesh               535.0     208
# 2                  Assam              5795.0    1612
# ...

# %%
pop1=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_population_density.csv')
pop1.drop(['Urban_Population','Urban_Population_Density','Total_Population_Density'],axis=1,inplace=True)
pop1.drop([29,36],inplace=True)
pop1.reset_index(drop=True,inplace=True)
pop1
# Out:
#                           State/UT  Rural_Population Rural_Population_Density  \
# 0                 Andhra Pradesh**          34256000                      216
# 1                Arunachal Pradesh           1141000                      NaN
# 2                            Assam          29492000                      382
# 3                            Bihar         107187000                     1167
# 4                     Chhattisgarh          21557000                      164
# 5                              Goa            421000                      145
# 6                          Gujarat          36380000                      193
# 7                          Haryana          17374000                      411
# 8                 Himachal Pradesh           6608000                      119
# 9                        Jharkhand          28313000                      365
# 10                       Karnataka          37815000                      204
# ...

# %%
ar1=pd.read_csv(r'C:\Users\parvp\Downloads\Rural Health\archive\rhs_villages_districs_area.csv')
ar1.drop(['Urban_Area','Number_of_Districts','Number_of_Villages','Tribal_Area'],axis=1,inplace=True)
ar1.fillna(value=0,inplace=True)
ar1.drop([29,36],inplace=True)
ar1.reset_index(drop=True, inplace=True)
ar1['Rural_Area'][1]=83743.0
ar1['Rural_%'][1]=100.0
ar1
# Out:
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\parvp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                           State/UT  Rural_Area  Total_Area  Rural_%
# 0                  Andhra Pradesh*   158856.00    162975.0    97.47
# 1                Arunachal Pradesh    83743.00     83743.0   100.00
# 2                            Assam    77178.12     78438.0    98.39
# 3                            Bihar    91838.28     94163.0    97.53
# ...

# %%
##concat##
d3['Rural_Population']=pop1['Rural_Population']
d3['Rural_Population_Density']=pop1['Rural_Population_Density']
d3['Rural_Population_%']=pop1['Rural_Population_%']
d3['Rural_Area']=ar1['Rural_Area']
d3['Total_Area']=ar1['Total_Area']
d3['Rural_%']=ar1['Rural_%']
d3
# Out:
#                 State/UT  HealthCare Centers  Doctor  \
# 0         Andhra Pradesh              8720.0    2113
# 1      Arunachal Pradesh               535.0     208
# 2                  Assam              5795.0    1612
# 3                  Bihar             10871.0    1869
# 4           Chhattisgarh              6167.0     450
# 5                    Goa               279.0      89
# 6                Gujarat             10987.0    1503
# 7                Haryana              3120.0     518
# 8       Himachal Pradesh              2741.0     492
# 9              Jharkhand              4310.0     401
# 10             Karnataka             11553.0    2323
# 11                Kerala              6405.0    1201
# 12        Madhya Pradesh             11734.0    1111
# 13           Maharashtra             12754.0    3247
# 14               Manipur               520.0     315
# 15             Meghalaya               587.0     194
# 16               Mizoram               377.0      58
# ...

# %%
##Density##
d3['HealthCare Density']=d3['HealthCare Centers']/d3['Rural_Area']
d3['Doctor Density']=d3['Doctor']/d3['Rural_Area']
d3['HealthCare&Nursing Staff Density']=d3['HealthCare&Nursing Staff']/d3['Rural_Area']
d3['Secondline HealthCare Centers Density']=d3['Secondline HealthCare Centers']/d3['Rural_Area']
d3['Rural Pop to Doc Ratio']=d3['Rural_Population']/d3['Doctor']
d3['Rural Pop to HealthCare Staff Ratio']=d3['Rural_Population']/d3['HealthCare&Nursing Staff']
d3
# Out:
#                 State/UT  HealthCare Centers  Doctor  \
# 0         Andhra Pradesh              8720.0    2113
# 1      Arunachal Pradesh               535.0     208
# 2                  Assam              5795.0    1612
# 3                  Bihar             10871.0    1869
# 4           Chhattisgarh              6167.0     450
# 5                    Goa               279.0      89
# 6                Gujarat             10987.0    1503
# 7                Haryana              3120.0     518
# 8       Himachal Pradesh              2741.0     492
# 9              Jharkhand              4310.0     401
# 10             Karnataka             11553.0    2323
# 11                Kerala              6405.0    1201
# 12        Madhya Pradesh             11734.0    1111
# 13           Maharashtra             12754.0    3247
# 14               Manipur               520.0     315
# 15             Meghalaya               587.0     194
# 16               Mizoram               377.0      58
# ...

# %%
d3.sort_values(by=['HealthCare&Nursing Staff Density'],ascending=False)
# Out:
#                 State/UT  HealthCare Centers  Doctor  \
# 33           Lakshadweep                18.0      18
# 34            Puducherry                80.0      45
# 29  Dadra & Nagar Haveli               108.0      14
# 27           West Bengal             11618.0    1739
# 11                Kerala              6405.0    1201
# 5                    Goa               279.0      89
# 3                  Bihar             10871.0    1869
# 7                Haryana              3120.0     518
# 2                  Assam              5795.0    1612
# 22            Tamil Nadu             10518.0    2936
# 24               Tripura              1094.0     223
# 26         Uttar Pradesh             24369.0    3575
# 30                 Delhi                17.0      18
# 0         Andhra Pradesh              8720.0    2113
# 19                Punjab              3520.0     530
# 23             Telangana              5465.0    1471
# 10             Karnataka             11553.0    2323
# ...

# %%
.......................................####RESULT##.............................................................................
# Out:
#   File "<ipython-input-31-c09ca9d4c7bc>", line 1
#     .......................................####RESULT##.............................................................................
#          ^
# SyntaxError: invalid syntax

# %%
#####################SITUATION OF DOCTORS IN RURAL INDIA#################################################################

# %%
##2005

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Initialize the matplotlib figure
p1, p2 = plt.subplots(figsize=(15, 7))
q1=d1.sort_values(by=['Rural Pop to Doc Ratio'],ascending=False)
q2=q1[-5:]#Best Ratio
q1=q1[:5]#Worst Ratio


# Plot Sates having Worst Rural population to Doctor's Ratio in 2005
p1=sns.barplot(x="Rural Pop to Doc Ratio", y="State/UT", data=q1,
           palette="bone_r")

# Add informative axis label
p1.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Worst Rural population to Doctor's Ratio in 2005")
sns.despine(left=True, bottom=True)
p1.set(xlim=(0, 110000))

# %%
# Plot Sates having Best Rural population to Doctor's Ratio in 2005
p1=sns.barplot(x="Rural Pop to Doc Ratio", y="State/UT", data=q2,
            palette="cool")

# Add informative axis label
p1.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Best Rural population to Doctor's Ratio in 2005")
sns.despine(left=True, bottom=True)
p1.set(xlim=(0, 12000))

# %%
##2019

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Initialize the matplotlib figure
f1, f2 = plt.subplots(figsize=(15, 7))
e1=d2.sort_values(by=['Rural Pop to Doc Ratio'],ascending=False)
e2=e1[-5:]#Best Ratio
e1=e1[:5]#Worst Ratio


# Plot Sates having Worst Rural population to Doctor's Ratio in 2019
f1=sns.barplot(x="Rural Pop to Doc Ratio", y="State/UT", data=e1,
            palette="rocket")

# Add informative axis label
f1.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Worst Rural population to Doctor's Ratio in 2019")
sns.despine(left=True, bottom=True)
f1.set(xlim=(0, 75000))

# %%
# Plot Sates having Best Rural population to Doctor's Ratio in 2019
sns.set_color_codes("pastel")
f2=sns.barplot(x="Rural Pop to Doc Ratio", y="State/UT", data=e2,
            palette="spring")

# Add informative axis label
f2.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Best Rural population to Doctor's Ratio in 2019")
sns.despine(left=True, bottom=True)
f2.set(xlim=(0, 9000))

# %%
# Initialize the matplotlib figure
f3, f4 = plt.subplots(figsize=(15, 7))
e3=d2.sort_values(by=['Doctor Density'],ascending=False)
e4=e3[-5:]#Best Ratio
e3=e3[:5]#Worst Ratio


# Plot Sates having Best Doctor's Density in 2019
f3=sns.barplot(x="Doctor Density", y="State/UT", data=e3,
            palette="GnBu")

# Add informative axis label
f3.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Best Doctor's Density in 2019")
sns.despine(left=True, bottom=True)
f3.set(xlim=(0, 1.25))

# %%
# Plot Sates having Worst Doctor's Density in 2019
sns.set_color_codes("pastel")
f4=sns.barplot(x="Doctor Density", y="State/UT", data=e4,
            palette="BuPu_r")

# Add informative axis label
f4.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Worst Doctor's Density in 2019")
sns.despine(left=True, bottom=True)
f4.set(xlim=(0, 0.005))

# %%
##2020 data

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Initialize the matplotlib figure and data
f, ax = plt.subplots(figsize=(15, 7))
t=d3.sort_values(by=['Rural Pop to Doc Ratio'],ascending=False)
u=t[-5:]
t=t[:5]


# Plot the states with Worst Rural Population to Doctor Ratio in 2020
ax=sns.barplot(x="Rural Pop to Doc Ratio", y="State/UT", data=t,
            palette="PuBu_r")

# Add a legend and informative axis label
ax.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst Rural Population to Doctor Ratio in 2020")
sns.despine(left=True, bottom=True)
ax.set(xlim=(500, 80000))

# %%
# Plot the states with Best Rural Population to Doctor Ratio
sns.set_color_codes("pastel")
f=sns.barplot(x="Rural Pop to Doc Ratio", y="State/UT", data=u,
            palette="OrRd")

# Add a informative axis label
f.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best Rural Population to Doctor Ratio in 2020")
sns.despine(left=True, bottom=True)
f.set(xlim=(100, 6000))

# %%
# Initialize the matplotlib figure and data
f3, f4 = plt.subplots(figsize=(15, 7))
v=d3.sort_values(by=['Doctor Density'],ascending=False)
w=v[-5:]
v=v[:5]


# Plot the states with Best Doctor Density in 2020
f3=sns.barplot(x="Doctor Density", y="State/UT", data=v,
            palette="spring_r")

# Add a legend and informative axis label
f3.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best Doctor Density in 2020")
sns.despine(left=True, bottom=True)
f3.set(xlim=(0,2.5))

# %%
# Plot the states with Worst Doctor Density
sns.set_color_codes("pastel")
f4=sns.barplot(x="Doctor Density", y="State/UT", data=w,
            palette="BuGn_r")

# Add a legend and informative axis label
f4.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst Doctor Density in 2020")
sns.despine(left=True, bottom=True)
f4.set(xlim=(0,0.006))

# %%
##Map of Rural Population to Doctor's Ratio in 2005
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d1['State/UT'],
    z=d1['Rural Pop to Doc Ratio'],

    autocolorscale=False,
    colorscale='algae',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Rural Population:Doctor"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=5000,
        dtick=5000,

        xanchor='left',
        x=0.005,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Rural Population to Doctors Ratio in India by State/UT in 2005",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of Rural Population to Doctor's Ratio in 2019
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d2['State/UT'],
    z=d2['Rural Pop to Doc Ratio'],

    autocolorscale=False,
    colorscale='algae',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Rural Population:Doctor"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=5000,
        dtick=5000,

        xanchor='left',
        x=0.001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Rural Population to Doctors Ratio in India by State/UT in 2019",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of Rural Population to Doctor's Ratio in 2020
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d3['State/UT'],
    z=d3['Rural Pop to Doc Ratio'],

    autocolorscale=False,
    colorscale='algae',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Rural Population:Doctor"},

        thickness=10,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=5000,
        dtick=5000,

        xanchor='left',
        x=0.001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Rural Population to Doctors Ratio in India by State/UT in 2020",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##################################################STATE OF HEALTHCARE WORKERS IN INDIA##########################################

# %%
#2005

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Initialize the matplotlib figure
p3, p4 = plt.subplots(figsize=(15, 7))
q3=d1.sort_values(by=['Rural Pop to HealthCare Staff Ratio'],ascending=False)
q4=q3[-5:]#Best Ratio
q3=q3[:5]#Worst Ratio


# Plot Sates having Worst Rural population to Doctor's Ratio in 2005
p3=sns.barplot(x="Rural Pop to HealthCare Staff Ratio", y="State/UT", data=q3,
           palette="copper")

# Add informative axis label
p3.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Worst Rural population to HealthCare and Nursing Staff's Ratio in 2005")
sns.despine(left=True, bottom=True)
p3.set(xlim=(0, 18000))

# %%
# Plot Sates having Worst Rural population to Doctor's Ratio in 2005
sns.set_color_codes("pastel")
p4=sns.barplot(x="Rural Pop to HealthCare Staff Ratio", y="State/UT", data=q4,
            palette="winter")

# Add informative axis label
p4.set(xlim=(0, 24), ylabel="",
       xlabel="Sates having Best population to HealthCare and Nursing Staff's Ratio in 2005")
sns.despine(left=True, bottom=True)
p4.set(xlim=(0, 2000))

# %%
#2019

# %%
# Initialize the matplotlib figure
g1, g2 = plt.subplots(figsize=(15, 7))
c1=d2.sort_values(by=['Rural Pop to HealthCare Staff Ratio'],ascending=False)
c2=c1[-5:]#Best Ratio
c1=c1[:5]#Worst Ratio


# Plot Sates having Worst Rural Population to HealthCare Staff Ratio in 2019
g1=sns.barplot(x="Rural Pop to HealthCare Staff Ratio", y="State/UT", data=c1,
            palette="binary")

# Add informative axis label
g1.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT having Worst Rural Population to HealthCare Staff Ratio in 2019")
sns.despine(left=True, bottom=True)
g1.set(xlim=(0, 7000))

# %%
# Plot Sates having Best Rural Population to HealthCare Staff Ratio in 2019
g2=sns.barplot(x="Rural Pop to HealthCare Staff Ratio", y="State/UT", data=c2,
            palette="PuRd")

# Add informative axis label
g2.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT having Best Rural Population to HealthCare Staff Ratio in 2019")
sns.despine(left=True, bottom=True)
g2.set(xlim=(0, 1000))

# %%
# Initialize the matplotlib figure
g3, g4 = plt.subplots(figsize=(15, 7))
c3=d2.sort_values(by=['HealthCare&Nursing Staff Density'],ascending=False)
c4=c3[-5:]#Best Ratio
c3=c3[:5]#Worst Ratio


# Plot Sates having Best HealthCare Staff Density in 2019
g3=sns.barplot(x="HealthCare&Nursing Staff Density", y="State/UT", data=c3,
            palette="gist_ncar_r")

# Add informative axis label
g3.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT having Best HealthCare Staff Density in 2019")
sns.despine(left=True, bottom=True)
g3.set(xlim=(0, 14))

# %%
# Plot Sates having Worst HealthCare Staff Density in 2019
g4=sns.barplot(x="HealthCare&Nursing Staff Density", y="State/UT", data=c4,
            palette="PuBuGn_r")

# Add informative axis label
g4.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT having Worst HealthCare Staff Density in 2019")
sns.despine(left=True, bottom=True)
g4.set(xlim=(0,0.05))

# %%
#2020

# %%
# Initialize the matplotlib figure and data
g1, g2 = plt.subplots(figsize=(15, 7))
l=d3.sort_values(by=['Rural Pop to HealthCare Staff Ratio'],ascending=False)
m=l[-5:]
l=l[:5]


# Plot the states with Worst Rural Population to Health Care Staff Ratio
g1=sns.barplot(x="Rural Pop to HealthCare Staff Ratio", y="State/UT", data=l,
            palette="pink")

# Add a legend and informative axis label
g1.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst Rural Population to Health Care Staff Ratio in 2020")
sns.despine(left=True, bottom=True)
g1.set(xlim=(500, 7500))

# %%
# Plot the states with Best Rural Population to Health Care Staff Ratio
sns.set_color_codes("pastel")
g2=sns.barplot(x="Rural Pop to HealthCare Staff Ratio", y="State/UT", data=m,
           palette="Wistia_r")

# Add a legend and informative axis label
g2.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best Rural Population to Health Care Staff Ratio in 2020")
sns.despine(left=True, bottom=True)
g2.set(xlim=(0, 1000))

# %%
# Initialize the matplotlib figure and data
g3, g4 = plt.subplots(figsize=(15, 7))
l1=d3.sort_values(by=['HealthCare&Nursing Staff Density'],ascending=False)
m1=l1[-5:]
l1=l1[:5]


# Plot the states with Best Health Care Staff Density
g3=sns.barplot(x="HealthCare&Nursing Staff Density", y="State/UT", data=l1,
            label="Total",palette="autumn")

# Add a legend and informative axis label
g3.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best HealthCare&Nursing Staff Density in 2020")
sns.despine(left=True, bottom=True)
g3.set(xlim=(0, 2))

# %%
# Plot the states with Worst Health Care Staff Density
g4=sns.barplot(x="HealthCare&Nursing Staff Density", y="State/UT", data=m1,
            palette="gist_gray")

# Add a legend and informative axis label
g4.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst HealthCare&Nursing Staff Density in 2020")
sns.despine(left=True, bottom=True)
g4.set(xlim=(0, 0.05))

# %%
##Map of Rural Population to HealthCare and Nursing Staff's Ratio in 2005
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d1['State/UT'],
    z=d1['Rural Pop to HealthCare Staff Ratio'],

    autocolorscale=False,
    colorscale='Burgyl',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Rural Pop.:Nursing Staff"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=500,

        xanchor='left',
        x=0.0001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Rural Pop. to HealthCare&Nursing Staff Ratio in India(2005)",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of Rural Population to HealthCare and Nursing Staff's Ratio in 2019
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d2['State/UT'],
    z=d2['Rural Pop to HealthCare Staff Ratio'],

    autocolorscale=False,
    colorscale='Burgyl',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Rural Pop:Nursing Staff"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=500,

        xanchor='left',
        x=0.0001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="HealthCare and Nursing Staff's Ratio in Rural India(2019)",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of Rural Population to HealthCare and Nursing Staff's Ratio in 2020
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d3['State/UT'],
    z=d3['Rural Pop to HealthCare Staff Ratio'],

    autocolorscale=False,
    colorscale='Burgyl',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Rural Pop:Nursing Staff"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=500,

        xanchor='left',
        x=0.0001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="HealthCare and Nursing Staff's Ratio in Rural India(2020)",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##########################################STATE OF PHCs IN INDIA##############################################################

# %%
#2005

# %%
#2019

# %%
# Initialize the matplotlib figure
h1, h2 = plt.subplots(figsize=(15, 7))
b1=d2.sort_values(by=['HealthCare Density'],ascending=False)
b2=b1[-5:]#Best Ratio
b1=b1[:5]#Worst Ratio


# Plot Sates having Best HealthCare Staff Density in 2019
h1=sns.barplot(x="HealthCare Density", y="State/UT", data=b1,
            palette="Reds")

# Add informative axis label
h1.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT having Best Primary HealthCare Density in 2019")
sns.despine(left=True, bottom=True)
h1.set(xlim=(0, 3))

# %%
# Plot Sates having Worst HealthCare Staff Density in 2019
h2=sns.barplot(x="HealthCare&Nursing Staff Density", y="State/UT", data=b2,
            palette="Purples_r")

# Add informative axis label
h2.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT having Worst HealthCare Staff Density in 2019")
sns.despine(left=True, bottom=True)
h2.set(xlim=(0,0.075))

# %%
#2020

# %%
# Initialize the matplotlib figure and data
h1,h2 = plt.subplots(figsize=(15, 7))
n=d3.sort_values(by=['HealthCare Density'],ascending=False)
o=n[-5:]
n=n[:5]


# Plot the states with Best HealthCare Density
h1=sns.barplot(x="HealthCare Density", y="State/UT", data=n,
            label="Total",palette="gnuplot2_r")

# Add a legend and informative axis label
h1.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best HealthCare Center's Density in 2020")
sns.despine(left=True, bottom=True)
h1.set(xlim=(0, 1))

# %%
# Plot the states with Worst HealthCare Density
h2=sns.barplot(x="HealthCare Density", y="State/UT", data=o,
            palette="Greys_r")

# Add a legend and informative axis label
h2.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst HealthCare Density in 2020")
sns.despine(left=True, bottom=True)
h2.set(xlim=(0, 0.025))

# %%
##Map of PHCs in Rural India in 2005
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d1['State/UT'],
    z=d1['HealthCare Centers'],

    autocolorscale=False,
    colorscale='Sunset',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "PHCs"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=2000,

        xanchor='left',
        x=0.0001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Primary Health Centers in Rural India by State/UT in 2005",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of PHCs in Rural India in 2019
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d2['State/UT'],
    z=d2['HealthCare Centers'],

    autocolorscale=False,
    colorscale='Sunset',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "PHCs"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=2000,

        xanchor='left',
        x=0.001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Primary Health Centers in Rural India by State/UT in 2019",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of PHCs in Rural India in 2020
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d3['State/UT'],
    z=d3['HealthCare Centers'],

    autocolorscale=False,
    colorscale='Sunset',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "PHCs"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=2000,

        xanchor='left',
        x=0.0001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Primary Health Centers in Rural India by State/UT in 2020",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##############################STATE OF SECONDLINE HEALTH CARE CENTERS IN INDIA################################################

# %%
#2005

# %%
#2019

# %%
# Initialize the matplotlib figure and data
i11,i22 = plt.subplots(figsize=(15, 7))
p11=d2.sort_values(by=['Secondline HealthCare Centers Density'],ascending=False)
q11=p11[-5:]
p11=p11[:5]


# Plot the states with Best SecondLineHealthCare Density
i11=sns.barplot(x="Secondline HealthCare Centers Density", y="State/UT", data=p11,
            palette="YlGnBu")

# Add a legend and informative axis label
i11.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best Secondline HealthCare Center's Density in 2019")
sns.despine(left=True, bottom=True)
i11.set(xlim=(0, 0.3))

# %%
# Plot the states with Worst Secondline HealthCare Centers Density
i22=sns.barplot(x="Secondline HealthCare Centers Density", y="State/UT", data=q11,
            palette="Blues_d")

# Add a legend and informative axis label
i22.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst Secondline HealthCare Center's Density in 2019")
sns.despine(left=True, bottom=True)
i22.set(xlim=(0, 0.008))

# %%
#2020

# %%
# Initialize the matplotlib figure and data
i1,i2 = plt.subplots(figsize=(15, 7))
p=d3.sort_values(by=['Secondline HealthCare Centers Density'],ascending=False)
q=p[-5:]
p=p[:5]


# Plot the states with Best SecondLineHealthCare Density
i1=sns.barplot(x="Secondline HealthCare Centers Density", y="State/UT", data=p,
            palette="hsv")

# Add a legend and informative axis label
i1.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Best Secondline HealthCare Center's Density in 2020")
sns.despine(left=True, bottom=True)
i1.set(xlim=(0, 0.3))

# %%
# Plot the states with Worst Secondline HealthCare Centers Density
i2=sns.barplot(x="Secondline HealthCare Centers Density", y="State/UT", data=q,
            palette="gist_yarg")

# Add a legend and informative axis label
i2.set(xlim=(0, 24), ylabel="",
       xlabel="States/UT with Worst Secondline HealthCare Center's Density in 2020")
sns.despine(left=True, bottom=True)
i2.set(xlim=(0, 0.008))

# %%
##Map of SHCs in Rural India in 2005
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d1['State/UT'],
    z=d1['Secondline HealthCare Centers'],

    autocolorscale=False,
    colorscale='haline_r',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "SHCs"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=500,

        xanchor='left',
        x=0.001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Secondary Health Centers in Rural India by State/UT in 2005",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of SHCs in Rural India in 2019
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d2['State/UT'],
    z=d2['Secondline HealthCare Centers'],

    autocolorscale=False,
    colorscale='haline_r',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "Sec. HealthCare Facility"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=500,

        xanchor='left',
        x=0.0001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Secondary Health Centers in Rural India by State/UT in 2019",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()

# %%
##Map of SHCs in Rural India in 2020
import plotly.graph_objects as go
fig = go.Figure(data=go.Choropleth(
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locationmode='geojson-id',
    locations=d3['State/UT'],
    z=d3['Secondline HealthCare Centers'],

    autocolorscale=False,
    colorscale='haline_r',
    marker_line_color='peachpuff',

    colorbar=dict(
         title={'text': "SHCs"},

        thickness=15,
        len=0.35,
        bgcolor='rgba(255,255,255,0.6)',

        tick0=0,
        dtick=500,

        xanchor='left',
        x=0.001,
        yanchor='bottom',
        y=0.05
    )
))

fig.update_geos(
    visible=False,
    projection=dict(
        type='conic conformal',
        parallels=[12.472944444, 35.172805555556],
        rotation={'lat': 24, 'lon': 80}
    ),
    lonaxis={'range': [68, 98]},
    lataxis={'range': [6, 38]}
)

fig.update_layout(
    title=dict(
        text="Secondary Health Centers in Rural India by State/UT in 2020",
        xanchor='center',
        x=0.5,
        yref='paper',
        yanchor='bottom',
        y=1,
        pad={'b': 10}
    ),
    margin={'r': 0, 't': 30, 'l': 0, 'b': 0},
    height=550,
    width=550
)

fig.show()
